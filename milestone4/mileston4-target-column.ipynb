# %% [markdown]
# # Input
#
# 1. Categorical input
# - 25% of data: Exceptional,
# - 50% of data: Good(mediocre)
# - 25% of data: Poor
#
# - Use percentile (quantile)
#
#
# 2. Numeric input
# - Put in numeric values, get numeric values out and categorize afterward
# - Same rule after model output to categorize

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../clean-data/final-final-df.csv')

# %%
columns_to_load = ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
                   'review_scores_checkin', 'review_scores_communication', 'review_scores_location','id']

austin = pd.read_csv('usa/Austin/listings_detailed.csv', usecols=columns_to_load)
chicago = pd.read_csv('usa/Chicago/listings_detailed.csv', usecols=columns_to_load)
denver = pd.read_csv('usa/Denver/listings_detailed-denver.csv', usecols=columns_to_load)
nashville = pd.read_csv('usa/Nashville/listings_detailed-nashville.csv', usecols=columns_to_load)
nola = pd.read_csv('usa/New Orleans/listings_detailed-nola.csv', usecols=columns_to_load)

df6 = pd.read_csv('all_data/listings_detailed.csv', usecols=columns_to_load)
df7 = pd.read_csv('all_data/listings_detailed 2.csv', usecols=columns_to_load)
df8 = pd.read_csv('all_data/listings_detailed 3.csv', usecols=columns_to_load)
df9 = pd.read_csv('all_data/listings_detailed 4.csv', usecols=columns_to_load)
df10 = pd.read_csv('all_data/listings_detailed 5.csv', usecols=columns_to_load)

df11 = pd.read_csv('all_data/listings_detailed 6.csv', usecols=columns_to_load)
df12 = pd.read_csv('all_data/listings_detailed 7.csv', usecols=columns_to_load)
df13 = pd.read_csv('all_data/listings_detailed 8.csv', usecols=columns_to_load)
df14 = pd.read_csv('all_data/listings_detailed 9.csv', usecols=columns_to_load)
df15 = pd.read_csv('all_data/listings_detailed 10.csv', usecols=columns_to_load)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 columns_to_load = ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness',
#       2                    'review_scores_checkin', 'review_scores_communication', 'review_scores_location','id']
# ----> 4 austin = pd.read_csv('usa/Austin/listings_detailed.csv', usecols=columns_to_load)
#       5 chicago = pd.read_csv('usa/Chicago/listings_detailed.csv', usecols=columns_to_load)
#       6 denver = pd.read_csv('usa/Denver/listings_detailed-denver.csv', usecols=columns_to_load)
#
# ...

# %%
dataframes = [austin, chicago, denver, nashville, nola, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]

# Concatenating all DataFrames
data_to_join = pd.concat(dataframes, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataframes = [austin, chicago, denver, nashville, nola, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]
#       3 # Concatenating all DataFrames
#       4 data_to_join = pd.concat(dataframes, ignore_index=True)
#
# NameError: name 'austin' is not defined

# %%
data_to_join
# Out:
#                         id  review_scores_rating  review_scores_accuracy  \
# 0                     5456                  4.84                    4.88
# 1                     5769                  4.90                    4.90
# 2                     6413                  4.97                    4.99
# 3                     6448                  4.97                    4.97
# 4                     8502                  4.53                    4.49
# ...                    ...                   ...                     ...
# 185984  818195233784141985                   NaN                     NaN
# 185985  818231243893035313                  5.00                    5.00
# 185986  818396267693629070                   NaN                     NaN
# 185987  818474518435984613                   NaN                     NaN
# 185988  818887060432463897                   NaN                     NaN
#
#         review_scores_cleanliness  review_scores_checkin  \
# ...

# %%
data
# Out:
#                         id    host_id  host_since           host_location  \
# 0       772438920837360569  382318476  2020-12-30                 Unknown
# 1                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 2                   484515     637272  2011-05-28  Buenos Aires Argentina
# 3                 45990221  365280298  2020-08-31               Irvine CA
# 4                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 184979  848982732370093638  107434423  2016-12-16             New York NY
# 184980  849181288802249186   31669178  2015-04-21              Chicago IL
# 184981  849355136099814004  165881852  2018-01-04              Chicago IL
# 184982  849539062724535549     100179  2010-03-28              Chicago IL
# 184983             1417110    7622794  2013-07-21              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %%
df_0_reviews = data[data['number_of_reviews'] == 0]
df_reviews = data[data['number_of_reviews'] != 0]

print(df_0_reviews.shape,df_reviews.shape)
# Out:
# (40989, 27) (143995, 27)

# %%
df_reviews['review_scores_value']
# Out:
# 0         5.00
# 1         4.68
# 2         4.44
# 3         4.64
# 4         4.83
#           ...
# 143990    4.35
# 143991    4.67
# 143992    4.98
# 143993    4.80
# 143994    4.86
# Name: review_scores_value, Length: 143995, dtype: float64

# %%
df_reviews
# Out:
#                         id    host_id  host_since           host_location  \
# 0       772438920837360569  382318476  2020-12-30                 Unknown
# 1                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 2                   484515     637272  2011-05-28  Buenos Aires Argentina
# 3                 45990221  365280298  2020-08-31               Irvine CA
# 4                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 143990               25879     101521  2010-03-31              Chicago IL
# 143991               28749      27506  2009-07-25                   Italy
# 143992               37738     162364  2010-07-09              Chicago IL
# 143993               71930     334241  2011-01-03              Chicago IL
# 143994               84042     334241  2011-01-03              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %% [markdown]
# # Joining all review-related column to the dataset

# %%
result_df = pd.merge(df_reviews, data_to_join, on='id', how='left', suffixes=('', '_data_to_join'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result_df = pd.merge(df_reviews, data_to_join, on='id', how='left', suffixes=('', '_data_to_join'))
#
# NameError: name 'data_to_join' is not defined

# %%
result_df
# Out:
#                         id    host_id  host_since           host_location  \
# 0       772438920837360569  382318476  2020-12-30                 Unknown
# 1                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 2                   484515     637272  2011-05-28  Buenos Aires Argentina
# 3                 45990221  365280298  2020-08-31               Irvine CA
# 4                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 143990               25879     101521  2010-03-31              Chicago IL
# 143991               28749      27506  2009-07-25                   Italy
# 143992               37738     162364  2010-07-09              Chicago IL
# 143993               71930     334241  2011-01-03              Chicago IL
# 143994               84042     334241  2011-01-03              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %%
result_df.isnull().sum()
# Out:
# id                                0
# host_id                           0
# host_since                        0
# host_location                     0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_has_profile_pic              0
# host_identity_verified            0
# neighborhood                      0
# latitude                          0
# longitude                         0
# room_type                         0
# accommodates                      0
# num_bath                          0
# bedrooms                          0
# beds                              0
# price                             0
# number_of_reviews                 0
# review_scores_value               0
# calculated_host_listings_count    0
# city                              0
# amenities_count                   0
# neighborhood_city                 0
# full_time_host                    0
# host_verifications_clean          0
# ...

# %% [markdown]
# # review_scores_value

# %%
result_df['review_scores_value'].describe()
# Out:
# count    143995.000000
# mean          4.686817
# std           0.452895
# min           0.000000
# 25%           4.610000
# 50%           4.800000
# 75%           4.940000
# max           5.000000
# Name: review_scores_value, dtype: float64

# %%
len(result_df[result_df['review_scores_value'] == 5])
# Out:
# 31088

# %%
result_df['review_scores_rating'].describe()
# Out:
# count    143995.000000
# mean          4.745986
# std           0.436968
# min           0.000000
# 25%           4.680000
# 50%           4.880000
# 75%           5.000000
# max           5.000000
# Name: review_scores_rating, dtype: float64

# %%
len(result_df[result_df['review_scores_rating'] == 5])
# Out:
# 41753

# %%
import matplotlib.pyplot as plt

# Setting up the figure
plt.figure(figsize=(10, 6))

# Plotting the distribution of review_scores_rating
plt.hist(result_df['review_scores_rating'].dropna(), alpha=0.5, color='blue', label='Review Scores Rating')

# Plotting the distribution of review_scores_value on the same figure
plt.hist(result_df['review_scores_value'].dropna(), alpha=0.5, color='red', label='Review Scores Value')

# Adding title, labels, grid, and legend
plt.title('Distribution of Review Scores Rating vs. Review Scores Value')
plt.xlabel('Review Scores')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.legend()

# Displaying the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Setting up the figure
plt.figure(figsize=(10, 6))

# KDE plot for review_scores_rating
sns.kdeplot(result_df['review_scores_rating'].dropna(), color="blue", label="Review Scores Rating", bw_adjust=0.5)

# KDE plot for review_scores_value
sns.kdeplot(result_df['review_scores_value'].dropna(), color="red", label="Review Scores Value", bw_adjust=0.5)

# Adding title, labels, and legend
plt.title('Distribution of Review Scores Rating vs. Review Scores Value')
plt.xlabel('Review Scores')
plt.ylabel('Density')
plt.legend()

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Creating a box plot for review_scores_value and review_scores_rating
plt.figure(figsize=(10, 6))

# Data preparation
data = [result_df['review_scores_value'].dropna(), result_df['review_scores_rating'].dropna()]

# Boxplot
plt.boxplot(data, vert=False, patch_artist=True, positions=[1, 2])

# Custom legend
value_patch = mpatches.Patch(color='blue', label='Review Scores Value')
rating_patch = mpatches.Patch(color='blue', label='Review Scores Rating')
plt.legend(handles=[value_patch, rating_patch])

# Adding title and labels
plt.title('Box Plot of Review Scores Value & Review Scores Rating')
plt.xlabel('Review Scores')
plt.yticks([1, 2], ['Review Scores Value', 'Review Scores Rating'])

plt.show()

# %%
result_df['review_scores_value'].describe()
# Out:
# count    143995.000000
# mean          4.686817
# std           0.452895
# min           0.000000
# 25%           4.610000
# 50%           4.800000
# 75%           4.940000
# max           5.000000
# Name: review_scores_value, dtype: float64

# %%
# Categorizing into four new categories
result_df['category'] = pd.cut(result_df['review_scores_value'],
                                      bins=[0, 4, 4.686817, 4.94, 5],
                                      labels=['poor', 'med', 'good', 'exceptional'],
                                      include_lowest=True)

# Counting how many data points fall into each category
category_counts = result_df['category'].value_counts()

category_counts
# Out:
# category
# good           62175
# med            36837
# exceptional    34900
# poor           10083
# Name: count, dtype: int64

# %%
result_df['review_scores_rating'].describe()
# Out:
# count    143995.000000
# mean          4.745986
# std           0.436968
# min           0.000000
# 25%           4.680000
# 50%           4.880000
# 75%           5.000000
# max           5.000000
# Name: review_scores_rating, dtype: float64

# %%
# Categorizing into four new categories
result_df['category'] = pd.cut(result_df['review_scores_rating'],
                                      bins=[0, 4, 4.7, 4.99, 5],
                                      labels=['poor', 'med', 'good', 'exceptional'],
                                      include_lowest=True)

# Counting how many data points fall into each category
category_counts = result_df['category'].value_counts()

category_counts
# Out:
# category
# good           63426
# exceptional    41753
# med            30817
# poor            7999
# Name: count, dtype: int64

# %% [markdown]
# # Going with
#
# - 0 < Poor <= 4
#
# - 4 < mediocre <= 4.686817 (mean)
#
# - 4.686817 < Good <= 4.94 (25% percentile)
#
# - 4.94 <= Exceptional < 5
#
# with **review_scores_value** column

# %%
# Categorizing into four new categories
data['target'] = pd.cut(data['review_scores_value'],
                                      bins=[0, 4, 4.8, 5],
                                      labels=['Poor', 'Average', 'Great'],
                                      include_lowest=True)

# Counting how many data points fall into each category
category_counts = data['target'].value_counts()

category_counts
# Out:
# target
# Great      71059
# Average    62853
# Poor       10083
# Name: count, dtype: int64

# %%
result_df
# Out:
#                         id    host_id  host_since           host_location  \
# 0       772438920837360569  382318476  2020-12-30                 Unknown
# 1                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 2                   484515     637272  2011-05-28  Buenos Aires Argentina
# 3                 45990221  365280298  2020-08-31               Irvine CA
# 4                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 143990               25879     101521  2010-03-31              Chicago IL
# 143991               28749      27506  2009-07-25                   Italy
# 143992               37738     162364  2010-07-09              Chicago IL
# 143993               71930     334241  2011-01-03              Chicago IL
# 143994               84042     334241  2011-01-03              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %%
result_df['target'].isnull().sum()
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# Setting up the figure for plotting
plt.figure(figsize=(10, 6))

# Creating a count plot for the 'target' column
ax = sns.countplot(x='target', data=data, order=['Poor', 'Average', 'Great'], palette='Set2')

# Calculating the total number of non-NaN entries for percentage calculation
total = len(data['target'].dropna())

# Annotating each bar with the count and percentage
for p in ax.patches:
    count = p.get_height()  # The height of the bar is the count of values in this category
    percentage = f'{100 * count / total:.1f}%'  # Calculating the percentage of the total
    ax.annotate(f'{count}\n({percentage})', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 10),
                textcoords='offset points')

# Setting the title and labels
plt.title('Distribution of Review Scores Categories')
plt.xlabel('Category')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Optional: Rotate the x-axis labels for better readability

# Showing the plot
plt.show()
# Out:
# /var/folders/m0/76k8l35x2p15kn84b0cplr8c0000gn/T/ipykernel_97770/2738370031.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='target', data=data, order=['Poor', 'Average', 'Great'], palette='Set2')

# %%
data
# Out:
#                         id    host_id  host_since           host_location  \
# 0       772438920837360569  382318476  2020-12-30                 Unknown
# 1                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 2                   484515     637272  2011-05-28  Buenos Aires Argentina
# 3                 45990221  365280298  2020-08-31               Irvine CA
# 4                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 184979  848982732370093638  107434423  2016-12-16             New York NY
# 184980  849181288802249186   31669178  2015-04-21              Chicago IL
# 184981  849355136099814004  165881852  2018-01-04              Chicago IL
# 184982  849539062724535549     100179  2010-03-28              Chicago IL
# 184983             1417110    7622794  2013-07-21              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %%
# Correcting the syntax and dropping specified columns from result_df
result_df = result_df.drop(columns=['category', 'review_scores_accuracy', 'review_scores_cleanliness',
                                    'review_scores_checkin', 'review_scores_communication', 'review_scores_location','review_scores_rating'])

# %%
result_df
# Out:
#                         id    host_id  host_since           host_location  \
# 0       772438920837360569  382318476  2020-12-30                 Unknown
# 1                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 2                   484515     637272  2011-05-28  Buenos Aires Argentina
# 3                 45990221  365280298  2020-08-31               Irvine CA
# 4                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 143990               25879     101521  2010-03-31              Chicago IL
# 143991               28749      27506  2009-07-25                   Italy
# 143992               37738     162364  2010-07-09              Chicago IL
# 143993               71930     334241  2011-01-03              Chicago IL
# 143994               84042     334241  2011-01-03              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %%
data.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_since                            0
# host_location                         0
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighborhood                          0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# num_bath                              0
# bedrooms                              0
# beds                                  0
# price                                 0
# number_of_reviews                     0
# review_scores_value               40989
# calculated_host_listings_count        0
# city                                  0
# amenities_count                       0
# ...

# %%
# Save as a new csv file
data.to_csv('../clean-data/final_data_for_modeling.csv', index=False)

# %%
df_0_reviews.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# host_since                            0
# host_location                         0
# host_is_superhost                     0
# host_listings_count                   0
# host_total_listings_count             0
# host_has_profile_pic                  0
# host_identity_verified                0
# neighborhood                          0
# latitude                              0
# longitude                             0
# room_type                             0
# accommodates                          0
# num_bath                              0
# bedrooms                              0
# beds                                  0
# price                                 0
# number_of_reviews                     0
# review_scores_value               40989
# calculated_host_listings_count        0
# city                                  0
# amenities_count                       0
# ...

# %%
df_0_reviews.to_csv('clean-data/target_column_with_zero_review.csv', index=False)

# %%
df = pd.read_csv('../clean-data/final_data_for_modeling.csv')
# Out:
# /var/folders/m0/76k8l35x2p15kn84b0cplr8c0000gn/T/ipykernel_97770/609870530.py:1: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../clean-data/final_data_for_modeling.csv')

# %%
df
# Out:
#                         id    host_id  host_since           host_location  \
# 0       772438920837360569  382318476  2020-12-30                 Unknown
# 1                 33271346  118856968  2017-03-02      Fort Lauderdale FL
# 2                   484515     637272  2011-05-28  Buenos Aires Argentina
# 3                 45990221  365280298  2020-08-31               Irvine CA
# 4                 48030650  131978491  2017-05-25                Miami FL
# ...                    ...        ...         ...                     ...
# 184979  848982732370093638  107434423  2016-12-16             New York NY
# 184980  849181288802249186   31669178  2015-04-21              Chicago IL
# 184981  849355136099814004  165881852  2018-01-04              Chicago IL
# 184982  849539062724535549     100179  2010-03-28              Chicago IL
# 184983             1417110    7622794  2013-07-21              Chicago IL
#
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# ...

# %%
df['target'].value_counts()
# Out:
# target
# Great      71059
# Average    62853
# Poor       10083
# Name: count, dtype: int64
